# %%
import argparse
from collections import defaultdict
import re
from typing import List, Pattern, Tuple

FORMALITY_PHRASES = re.compile("(\[F\](.*?)\[/F\])")


def compute_score(
    hypotheses: str,
    annotated_formal_refs: str,
    annotated_informal_refs: str,
    tok_split: bool=True
) -> Tuple[float, float]:
    """
    Compute formal and informal matched-accuracy scores.

    Args:
        hypothesis: file containing system detokenized output translations
        annotated_formal_refs: formal reference file with annotated grammatical formality
        annotated_informal_refs: informal reference file with annotated grammatical formality
        tok_split: Split hypotheses and references into tokens before phrase matching.

    Returns:
        (formal_acc, informal_acc), the formal accuracy and informal matched-accuracy scores respectively.
    """
    hypotheses = _read_lines(hypotheses)
    annotated_references_formal = _read_lines(annotated_formal_refs)
    annotated_references_informal = _read_lines(annotated_informal_refs)

    if not (len(hypotheses) == len(annotated_references_formal) == len(annotated_references_informal) > 0):
        raise RuntimeError("Empty or mismatched hypotheses and reference files.")

    scores = defaultdict(int)
    count_neutral = 0
    for hyp, ref_formal, ref_informal in zip(hypotheses, annotated_references_formal, annotated_references_informal):
        formal_phrases_hyp, formal_phrases_ref = get_matching_phrases(hyp, ref_formal, tok_split, FORMALITY_PHRASES)
        informal_phrases_hyp, informal_phrases_ref = get_matching_phrases(hyp, ref_informal, tok_split, FORMALITY_PHRASES)
    
        label = predict_formality_label(formal_phrases_hyp, informal_phrases_hyp)
        print(hyp, formal_phrases_ref, informal_phrases_ref, label, formal_phrases_hyp, informal_phrases_hyp)
        if len(formal_phrases_ref) == 0:
            count_neutral+=1
        scores[f"ref_matched_count_{label}"] += 1
    n_matched = scores["ref_matched_count_INFORMAL"] + scores["ref_matched_count_FORMAL"]
    formal_acc = scores["ref_matched_count_FORMAL"]/n_matched if n_matched>0 else 0
    informal_acc = scores["ref_matched_count_INFORMAL"]/n_matched if n_matched>0 else 0
    print(scores)
    print("n_matched:", n_matched)
    print("Total samples:", len(hypotheses))
    print("True neutral:", count_neutral)
    return formal_acc, informal_acc


def get_matching_phrases(
    hyp: str,
    anno_ref: str,
    tok_split: bool=True,
    phrase_regex: Pattern=FORMALITY_PHRASES
):
    """
    Get annotated phrases that match in the hypothesis.

    Args:
        hyp: system hypothesis
        anno_ref: reference translation with annotated grammatical register
        tok_split: whether phrases should be split (on whitespace) into tokens before phrase matching
        phrase_regex: regular expression for finding references.

    Returns:
        list of annotated phrases occuring in the hypothesis.
    """
    anno_ph = re.findall(phrase_regex, anno_ref)
    if not tok_split:
        anno_ph_hyp = [ph for _, ph in anno_ph if ph in hyp]
    else:
        anno_ph_hyp = [ph for _, ph in anno_ph if set(ph.split(" ")).issubset(hyp.split(" "))]
    return anno_ph_hyp, anno_ph


def predict_formality_label(
    ph_formal_hyp: List[str],
    ph_informal_hyp: List[str]
) -> str:
    """
    Predict the formality label depending on the number of matched formal/informal phrases.

    Args:
        ph_formal_hyp: list of phrases in the hypothesis matching annotated formal reference phrases
        ph_informal_hyp: list of phrases in the hypothesis matching annotated informal reference phrases

    Returns:
        formality label, "FORMAL","INFORMAL","OTHER","NEUTRAL"
    """
    if ph_formal_hyp and not ph_informal_hyp:
        return "FORMAL"
    elif ph_informal_hyp and not ph_formal_hyp:
        return "INFORMAL"
    elif not ph_informal_hyp and not ph_formal_hyp:
        return "NEUTRAL"
    return "OTHER"

def _read_lines(file: str) -> List[str]:
    with open(file, "r", encoding="utf-8") as file:
        raw_text = [line.strip() for line in file.readlines()]
    return raw_text

# %%
whitespace_delimited_tokens = True
domain="combined"
hypotheses=f"../experiments/en-es/mBART/{domain}/out.dev"
# hypotheses="../../unpaired_res/formal.topical-chat.es"
formal_refs=f"../internal_split/en-es/dev.{domain}.formal.annotated.es"
informal_refs=f"../internal_split/en-es/dev.{domain}.informal.annotated.es"

# %%
formal_acc, informal_acc = compute_score(
        hypotheses, formal_refs, informal_refs, tok_split=whitespace_delimited_tokens
    )
# Out:
# Well there's actually a hidden subculture dedicated to find hidden Mickey mouse images in all things Disney, you should definitely check out! [('[F]debería[/F]', 'debería')] [('[F]deberías[/F]', 'deberías')] NEUTRAL [] []
# Me complace mucho que tu cana pueda ser donadora. [('[F]sus[/F]', 'sus')] [('[F]tus[/F]', 'tus')] NEUTRAL [] []
# Es cierto, pero creo que los gatos son más inteligentes que la mayoría de los políticos. [('[F]Puede imaginarse[/F]', 'Puede imaginarse')] [('[F]Puedes imaginarte[/F]', 'Puedes imaginarte')] NEUTRAL [] []
# No le garantizaría ganar el juego, pero lo haría mucho más fácil. [('[F]ganara[/F]', 'ganara'), ('[F]pase[/F]', 'pase')] [('[F]ganaras[/F]', 'ganaras'), ('[F]pases[/F]', 'pases')] NEUTRAL [] []
# Sí, eso tiene sentido, ¿tenen oído hablar del buque de 10 millones de dólares que tiene? [('[F]Ha oído[/F]', 'Ha oído')] [('[F]Has oído[/F]', 'Has oído')] NEUTRAL [] []
# Sí, y la mayoría de los lugares en los que viajas todavía puedes acceder a tu cuenta ya que está disponible en países excepto China, Siria, Corea del Norte y Crimea. [('[F]viaje[/F]', 'viaje'), ('[F]puede[/F]', 'puede'), ('[F]su[/F]', 'su')] [('[F]viajes[/F]', 'viajes'), ('[F]puedes[/F]', 'puedes'), ('[F]tu[/F]', 'tu')] INFORMAL [] ['puedes', 'tu']
# I wonder if you get extra credit if you start growing your hair out for that class? lol I had a mythology and fantasy class in college. It was pretty good. [('[F]le[/F]', 'le'), ('[F]se deja[/F]', 'se deja')] [('[F]te[/F]', 'te'), ('[F]te dejas[/F]', 'te dejas')] NEUTRAL [] []
# No porque yo sea tan viejo como Shakespeare... ya que estaba vivo durante la época de Pocahontas, que es un poco más viejo que yo. [('[F]opina[/F]', 'opina')] [('[F]opinas[/F]', 'opinas')] NEUTRAL [] []
# lol, sé que tienes que disfrutar si intentas algo nuevo, hacer algo diferente con agua es interesante, pero lapping it up like a cat no soa divertido. [] [] NEUTRAL [] []
# ¿Has visto el film Blazing Saddles? [('[F]Ha[/F]', 'Ha')] [('[F]Has[/F]', 'Has')] NEUTRAL [] []
# Hemos visto a los Goonies? [('[F]Vio[/F]', 'Vio')] [('[F]Viste[/F]', 'Viste')] NEUTRAL [] []
# He tomado yoga antes pero necesito un par de clases más antes de ser más flexible. [('[F]con usted[/F]', 'con usted'), ('[F]pase[/F]', 'pase')] [('[F]contigo[/F]', 'contigo'), ('[F]pases[/F]', 'pases')] NEUTRAL [] []
# Me gusta la melodía y la armonía. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] NEUTRAL [] []
# ¿Es el sol que bloquea su señal de Internet esta noche? [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] FORMAL ['su'] []
# No me gustaría trabajar para el film "Wars de Troyanos" que no ganó más de 309 dólares con un presupuesto de 15 millones! [('[F]con usted[/F]', 'con usted')] [('[F]contigo[/F]', 'contigo')] NEUTRAL [] []
# Yo me he enterado de que la gente quiere grabar su propia identidad, Jazz es bastante grande. [('[F]Podría[/F]', 'Podría')] [('[F]Podrías[/F]', 'Podrías')] NEUTRAL [] []
# No me he oído pero estoy totalmente de acuerdo con usted. [('[F]con usted[/F]', 'con usted')] [('[F]contigo[/F]', 'contigo')] NEUTRAL [] []
# Por otra parte, ¿qué crees de Chris Pratt? [('[F]piensa[/F]', 'piensa')] [('[F]piensas[/F]', 'piensas')] NEUTRAL [] []
# Me gustaba jugar a Pokemon, has jugado alguna vez el juego o has visto la serie? [('[F]ha jugado[/F]', 'ha jugado'), ('[F]ha visto[/F]', 'ha visto')] [('[F]has jugado[/F]', 'has jugado'), ('[F]has visto[/F]', 'has visto')] INFORMAL [] ['has jugado', 'has visto']
# Interesante. Se deen muchas lluvias en Oregon, ¿encontrés alguna vez? [('[F]ha[/F]', 'ha')] [('[F]has[/F]', 'has')] NEUTRAL [] []
# No no me he percatado de ese episodio, así que te gusta la música pop? [('[F]le[/F]', 'le')] [('[F]te[/F]', 'te')] INFORMAL [] ['te']
# i don't believe i have seen those. i don't follow the marvel series too closely. i do know chris pratt plays a role in a show on tv, parks and rec. have you seen it? [('[F]ha visto[/F]', 'ha visto')] [('[F]has visto[/F]', 'has visto')] NEUTRAL [] []
# Unicef donó agua limpia cuando no utilizas tu hpone [('[F]utiliza[/F]', 'utiliza')] [('[F]utilizas[/F]', 'utilizas')] INFORMAL [] ['utilizas']
# Estoy de acuerdo, así que te gustan las ficciones? [('[F]le[/F]', 'le')] [('[F]te[/F]', 'te')] INFORMAL [] ['te']
# Usted mira películas que es su favorita? [('[F]Ve[/F]', 'Ve'), ('[F]su[/F]', 'su')] [('[F]Ves[/F]', 'Ves'), ('[F]tu[/F]', 'tu')] FORMAL ['su'] []
# Si, no hay mucho que hacer en Buffalo, excepto ir al centro comercial! [('[F]ha[/F]', 'ha'), ('[F]ha[/F]', 'ha'), ('[F]su[/F]', 'su')] [('[F]has[/F]', 'has'), ('[F]has[/F]', 'has'), ('[F]tu[/F]', 'tu')] NEUTRAL [] []
# ¿Algunha vez ha jugado el juego usted mismo, no he, no soy originario de los Estados Unidos. [('[F]Ha[/F]', 'Ha')] [('[F]Has[/F]', 'Has')] NEUTRAL [] []
# No me molesta mucho el género, mientras me enenenenen. [('[F]ve[/F]', 've')] [('[F]ves[/F]', 'ves')] NEUTRAL [] []
# Lebron está bien esta temporada, está muy enfocado. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] NEUTRAL [] []
# Yep that is cool LOL. What do you think about Vin Diesel getting a secret script that says what Groot is actually speaking in the movies [('[F]le[/F]', 'le')] [('[F]te[/F]', 'te')] NEUTRAL [] []
# que es interesante me he preguntado siempre que, utiliza Google para sus búsquedas? o otro sitio web? [('[F]Utiliza[/F]', 'Utiliza'), ('[F]sus[/F]', 'sus')] [('[F]Utilizas[/F]', 'Utilizas'), ('[F]tus[/F]', 'tus')] FORMAL ['sus'] []
# He oído que Smallville originalmente iba a ser sobre Bruce Wayne que se convirtiera en Batman. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] NEUTRAL [] []
# Nice me too! No he oído hablar de eso, eso sería fantástico, Usted usa su propio coche o un car? [('[F]utiliza[/F]', 'utiliza'), ('[F]su[/F]', 'su')] [('[F]utilizas[/F]', 'utilizas'), ('[F]tu[/F]', 'tu')] FORMAL ['su'] []
# Jane McGongiai fue la diseñadora de juegos detrás de ese estudio, bastante cool. [('[F]sus[/F]', 'sus')] [('[F]tus[/F]', 'tus')] NEUTRAL [] []
# Yup. well it was nice chatting with you have a good day. [('[F]con usted[/F]', 'con usted'), ('[F]pase[/F]', 'pase')] [('[F]contigo[/F]', 'contigo'), ('[F]pases[/F]', 'pases')] NEUTRAL [] []
# Yo me he acostumbrado a jugar a Nintendo en mi juventud. [('[F]usted[/F]', 'usted')] [('[F]tú[/F]', 'tú')] NEUTRAL [] []
# Lo mismo es aquí, intente hacer de hoy su día perfecto, sin embargo. [('[F]Intente[/F]', 'Intente'), ('[F]su[/F]', 'su')] [('[F]Intenta[/F]', 'Intenta'), ('[F]tu[/F]', 'tu')] FORMAL ['su'] []
# que debe ser un espectacular espectáculo para verlo comer. una buena manera de liberarse de sus enemigos! LOL [('[F]deshacerse[/F]', 'deshacerse'), ('[F]sus[/F]', 'sus')] [('[F]deshacerte[/F]', 'deshacerte'), ('[F]tus[/F]', 'tus')] FORMAL ['sus'] []
# ¿Qué piensas sobre el nombre ''Cathode Ray Tube Amusement Devices''? [('[F]opina[/F]', 'opina')] [('[F]opinas[/F]', 'opinas')] NEUTRAL [] []
# Interesante. Hes visto la película? [('[F]Ha visto[/F]', 'Ha visto')] [('[F]Has visto[/F]', 'Has visto')] NEUTRAL [] []
# Aceptado. ¿Tiene previsto ver la última inenenenable: M. I - Fallout? [('[F]Va[/F]', 'Va')] [('[F]Vas[/F]', 'Vas')] NEUTRAL [] []
# Yo lo doy, cada año un nuevo traje, usted sabe que los investigadores de paendas toman un traje de paendas para el trabajo. [('[F]sabe[/F]', 'sabe')] [('[F]sabes[/F]', 'sabes')] FORMAL ['sabe'] []
# Yo sé algunos como él trabajaba en Bubba Gump. [('[F]con usted[/F]', 'con usted')] [('[F]contigo[/F]', 'contigo')] NEUTRAL [] []
# Hi im doing great how about yourself? [('[F]usted[/F]', 'usted'), ('[F]Le[/F]', 'Le')] [('[F]ti[/F]', 'ti'), ('[F]Te[/F]', 'Te')] NEUTRAL [] []
# Yeah. Me parece joven. [('[F]con usted[/F]', 'con usted')] [('[F]contigo[/F]', 'contigo')] NEUTRAL [] []
# Me ha gustado en Beauty and the Beast. [('[F]tiene[/F]', 'tiene')] [('[F]tienes[/F]', 'tienes')] NEUTRAL [] []
# Me gusta. [('[F]Le[/F]', 'Le')] [('[F]Te[/F]', 'Te')] NEUTRAL [] []
# La mayoría de la gente cree que todos los tientos son tientos asesinas, pero he leído que todos los tientos no son tientos asesinas. [('[F]Ha[/F]', 'Ha')] [('[F]Has[/F]', 'Has')] NEUTRAL [] []
# Good Morning! ¿Has oído hablar de K-Pop? [('[F]Ha[/F]', 'Ha')] [('[F]Has[/F]', 'Has')] NEUTRAL [] []
# No he visto un film de disney en un tiempo. ¿Tiene una recomendación? [('[F]tiene[/F]', 'tiene')] [('[F]tienes[/F]', 'tienes')] NEUTRAL [] []
# como usted vende, es como usted realmente tiene que hacerlo por un coste bajo. [('[F]usted[/F]', 'usted'), ('[F]usted[/F]', 'usted')] [('[F]tú[/F]', 'tú'), ('[F]tú[/F]', 'tú')] FORMAL ['usted', 'usted'] []
# que simplemente se siente tan grande que puede parecer poco en el principio, es realmente super grande, cosas que están haciendo para usted. [('[F]usted[/F]', 'usted')] [('[F]ti[/F]', 'ti')] NEUTRAL [] []
# Siempre hay algo que hacer, me refiero a que vale la pena tu tiempo como odio la pérdida de mi tiempo. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] INFORMAL [] ['tu']
# porque las respuestas son siempre corregidas, pero a veces no son corregidas. [('[F]enseñe[/F]', 'enseñe')] [('[F]enseñes[/F]', 'enseñes')] NEUTRAL [] []
# Cuando se accede a un reembolso del billete, por favor enenenen su número de PIN, registro de nombre de viajero y añadan su número de billete. [('[F]introduzca[/F]', 'introduzca'), ('[F]su[/F]', 'su'), ('[F]añada[/F]', 'añada'), ('[F]su[/F]', 'su')] [('[F]introduce[/F]', 'introduce'), ('[F]tu[/F]', 'tu'), ('[F]añade[/F]', 'añade'), ('[F]tu[/F]', 'tu')] FORMAL ['su', 'su'] []
# Hemos tomado algunas fotos de tu Facebook y te crearemos un sitio de encuentros. [('[F]dicen[/F]', 'dicen'), ('[F]su[/F]', 'su'), ('[F]crearle[/F]', 'crearle')] [('[F]decís[/F]', 'decís'), ('[F]su[/F]', 'su'), ('[F]crearle[/F]', 'crearle')] NEUTRAL [] []
# Es como una TV realmente buena por cuarenta dólares o algo y él correba literalmente a la calle 14 a las 10 de la noche, pero tiene esto. [] [] NEUTRAL [] []
# puedes ver, podría ser más una cosa en la que te has ido a casa, tus hijos se cuidan, en la que han estado [('[F]puede[/F]', 'puede'), ('[F]llegara[/F]', 'llegara'), ('[F]sus[/F]', 'sus')] [('[F]puedes[/F]', 'puedes'), ('[F]llegaras[/F]', 'llegaras'), ('[F]tus[/F]', 'tus')] INFORMAL [] ['puedes', 'tus']
# Los niños siempre van en primer lugar, antes de trabajar, por lo que siempre es la familia en primer lugar. [] [] NEUTRAL [] []
# Así que me diga de tu mejor amigo de infancia. [('[F]Cuénteme[/F]', 'Cuénteme'), ('[F]su[/F]', 'su')] [('[F]Cuéntame[/F]', 'Cuéntame'), ('[F]tu[/F]', 'tu')] INFORMAL [] ['tu']
# Especialmente porque me parece, a diferencia de su familia, en su caso ningún de nosotros realmente seguir el camino por así decirlo. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] FORMAL ['su'] []
# ¿Has inenenenado una tarjeta de crédito para inenenar una tarjeta de crédito en tu cuenta Freelancer? [('[F]Puso[/F]', 'Puso'), ('[F]su[/F]', 'su')] [('[F]Pusiste[/F]', 'Pusiste'), ('[F]tu[/F]', 'tu')] INFORMAL [] ['tu']
# Así que usted básicamente va, I am closing my account [('[F]basicamente usted va[/F]', 'basicamente usted va')] [('[F]basicamente tú vas[/F]', 'basicamente tú vas')] NEUTRAL [] []
# Bueno, y sabe, me pregunto si los hombres encuentran una competencia para superar como él me dijo me deje tu número de mi hermana, [('[F]sabe[/F]', 'sabe'), ('[F]su[/F]', 'su')] [('[F]sabes[/F]', 'sabes'), ('[F]tu[/F]', 'tu')] INFORMAL [] ['tu']
# Pero me he preguntado cómo te sentis con su relación con ellos, es como si tuen una relación, pensas como si tuen una relación [('[F]se siente[/F]', 'se siente'), ('[F]su[/F]', 'su'), ('[F]tuviera[/F]', 'tuviera'), ('[F]piensa[/F]', 'piensa'), ('[F]su[/F]', 'su')] [('[F]te sientes[/F]', 'te sientes'), ('[F]tu[/F]', 'tu'), ('[F]tuvieras[/F]', 'tuvieras'), ('[F]piensas[/F]', 'piensas'), ('[F]tu[/F]', 'tu')] FORMAL ['su', 'su'] []
# Usted sabe que necesita alentar a alguien, necesita alentar a alguien con quien hablar. [('[F]Usted sabe[/F]', 'Usted sabe'), ('[F]necesita[/F]', 'necesita'), ('[F]necesita[/F]', 'necesita')] [('[F]Tú sabes[/F]', 'Tú sabes'), ('[F]necesitas[/F]', 'necesitas'), ('[F]necesitas[/F]', 'necesitas')] FORMAL ['Usted sabe', 'necesita', 'necesita'] []
# Sin embargo, no me parece que el precio de los productos sea tan alto como el precio de los productos. [('[F]Qué piensa[/F]', 'Qué piensa')] [('[F]Qué piensas[/F]', 'Qué piensas')] NEUTRAL [] []
# (en verdad cuidar de) mis hijos mis padres saben eso. [('[F]usted pudiera[/F]', 'usted pudiera'), ('[F]fue criado[/F]', 'fue criado'), ('[F]sus[/F]', 'sus'), ('[F]lo haría[/F]', 'lo haría')] [('[F]tú pudieras[/F]', 'tú pudieras'), ('[F]fuiste criado[/F]', 'fuiste criado'), ('[F]tus[/F]', 'tus'), ('[F]lo harías[/F]', 'lo harías')] NEUTRAL [] []
# En la misma sesión, la Comisión aprobó el proyecto de resolución A/C.1/55/L.29 sin someterlo a votación (véase párr. [] [] NEUTRAL [] []
# yeah taking to the zoo you know what I'm saying [('[F]sabe[/F]', 'sabe')] [('[F]sabes[/F]', 'sabes')] NEUTRAL [] []
# No se ha extendido y ha dicho, nunca te has perdoado por morderte el brazo. [('[F]nunca se lamentó[/F]', 'nunca se lamentó'), ('[F]su[/F]', 'su')] [('[F]nunca te lamentaste[/F]', 'nunca te lamentaste'), ('[F]tu[/F]', 'tu')] NEUTRAL [] []
# Usted me da un amigo [('[F]da[/F]', 'da')] [('[F]das[/F]', 'das')] FORMAL ['da'] []
# Y un modo de expresarse es, como saben, los ejemplos que ha dado significan que hay mucho más cinismo. [('[F]usted sabe[/F]', 'usted sabe'), ('[F]usted dio[/F]', 'usted dio')] [('[F]tú sabes[/F]', 'tú sabes'), ('[F]tú diste[/F]', 'tú diste')] NEUTRAL [] []
# you know just like somehow you know they were able to pack it in the bag and pull, they are all new and just drop it off over there [('[F]sabe[/F]', 'sabe'), ('[F]sabe[/F]', 'sabe')] [('[F]sabes[/F]', 'sabes'), ('[F]sabes[/F]', 'sabes')] NEUTRAL [] []
# ¿Qué es tu segundo favorito entonces? [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] INFORMAL [] ['tu']
# La señora que dirigió el lugar era muy acogedora, muy acogedora. [('[F]lo[/F]', 'lo')] [('[F]te[/F]', 'te')] NEUTRAL [] []
# (Well, I remember) Tengo una pregunta para ti. [('[F]usted[/F]', 'usted'), ('[F]Tuvo[/F]', 'Tuvo')] [('[F]ti[/F]', 'ti'), ('[F]Tuviste[/F]', 'Tuviste')] NEUTRAL [] []
# Por supuesto, ¿puedo obtener su código de IP y nombre de la calle, por favor? [('[F]puede darme también[/F]', 'puede darme también'), ('[F]su[/F]', 'su')] [('[F]puedes darme también[/F]', 'puedes darme también'), ('[F]tu[/F]', 'tu')] FORMAL ['su'] []
# No sus consultas pueden ser soportadas por la compra de entradas a través de este sitio web. [('[F]sus[/F]', 'sus'), ('[F]compra[/F]', 'compra'), ('[F]usted compra[/F]', 'usted compra'), ('[F]su[/F]', 'su'), ('[F]tiene[/F]', 'tiene')] [('[F]tus[/F]', 'tus'), ('[F]compras[/F]', 'compras'), ('[F]tú compras[/F]', 'tú compras'), ('[F]tu[/F]', 'tu'), ('[F]tienes[/F]', 'tienes')] FORMAL ['sus', 'compra'] []
# Y lo devolve a Amazon en general? [('[F]devuelve[/F]', 'devuelve')] [('[F]devuelves[/F]', 'devuelves')] NEUTRAL [] []
# van a contar una historia sobre sus vidas sexuales para gustar a un público lleno de gente y Peter [('[F]va[/F]', 'va'), ('[F]su[/F]', 'su')] [('[F]vas[/F]', 'vas'), ('[F]tu[/F]', 'tu')] NEUTRAL [] []
# pero sus precios son tan grandes, y entonces tienen tantas cosas que tienes que simplemente intentar [('[F]usted tiene[/F]', 'usted tiene')] [('[F]tú tienes[/F]', 'tú tienes')] NEUTRAL [] []
# Yo no quería decir nada, ni siquiera sabía cómo decirlo y diría que me cortaron. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] NEUTRAL [] []
# Oh my god, I hate Will Farrells. So what's your favourite movie? The movie with Will Farell. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] NEUTRAL [] []
# you know, esto parece que la línea puede ser realmente larga. [('[F]sabe[/F]', 'sabe')] [('[F]sabes[/F]', 'sabes')] NEUTRAL [] []
# Okay, ya está todo claro, entra en tu apartamento o les deja entrar, así que, como saben, eso va a continuar para siempre. [('[F]Métase[/F]', 'Métase'), ('[F]su[/F]', 'su'), ('[F]déjelos[/F]', 'déjelos'), ('[F]sabe[/F]', 'sabe'), ('[F]Mire[/F]', 'Mire')] [('[F]Métete[/F]', 'Métete'), ('[F]tu[/F]', 'tu'), ('[F]déjalos[/F]', 'déjalos'), ('[F]sabes[/F]', 'sabes'), ('[F]Mira[/F]', 'Mira')] INFORMAL [] ['tu']
# You just, la única cosa que está enjuiciado es, su fin de semana y sus vacaciones y todas las cosas de eso están reservadas. [('[F]su[/F]', 'su'), ('[F]sus[/F]', 'sus')] [('[F]tu[/F]', 'tu'), ('[F]tus[/F]', 'tus')] FORMAL ['su', 'sus'] []
# tu madre te envía regalos inútiles. [('[F]su[/F]', 'su'), ('[F]le[/F]', 'le')] [('[F]tu[/F]', 'tu'), ('[F]te[/F]', 'te')] INFORMAL [] ['tu', 'te']
# No no tu hermano o ti mismo como a quien consideras tu primo [('[F]su[/F]', 'su'), ('[F]usted mismo[/F]', 'usted mismo'), ('[F]considera[/F]', 'considera'), ('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu'), ('[F]tú mismo[/F]', 'tú mismo'), ('[F]consideras[/F]', 'consideras'), ('[F]tu[/F]', 'tu')] INFORMAL [] ['tu', 'consideras', 'tu']
# Eso significa que no tienes suficiente espacio en tu ordenador por alguna razón. [('[F]no tiene[/F]', 'no tiene'), ('[F]su[/F]', 'su')] [('[F]no tienes[/F]', 'no tienes'), ('[F]tu[/F]', 'tu')] INFORMAL [] ['no tienes', 'tu']
# donde se sabe que se puede limpiar a sí mismo cuando se va a la lavandería en términos de aceites y olores y todo eso, absolutamente todo el mundo olentaba maravilloso, era simplemente la higiene y es incrible. [('[F]sabe[/F]', 'sabe'), ('[F]puede limpiarse[/F]', 'puede limpiarse'), ('[F]va[/F]', 'va')] [('[F]sabes[/F]', 'sabes'), ('[F]puedes limpiarte[/F]', 'puedes limpiarte'), ('[F]vas[/F]', 'vas')] FORMAL ['sabe', 'va'] []
# Si, son cool, ¿entendes lo que me digo? [('[F]sabe[/F]', 'sabe')] [('[F]sabes[/F]', 'sabes')] NEUTRAL [] []
# en el ordenador al mismo tiempo que lo comprobamos con tus amigos, tratar con tus hijos o tu banda que conoces, así que es un hecho de la vida muchas personas saen las noticias de esa manera. [('[F]sus[/F]', 'sus'), ('[F]apechugue[/F]', 'apechugue'), ('[F]sus[/F]', 'sus'), ('[F]su[/F]', 'su'), ('[F]sabe[/F]', 'sabe')] [('[F]tus[/F]', 'tus'), ('[F]apechuga[/F]', 'apechuga'), ('[F]tus[/F]', 'tus'), ('[F]tu[/F]', 'tu'), ('[F]sabes[/F]', 'sabes')] INFORMAL [] ['tus', 'tus', 'tu']
# ¿Cuántas horas al año gastan en conducir en comparación con cómo pueden utilizarlo para ser más productivos? [('[F]esté[/F]', 'esté'), ('[F]su[/F]', 'su'), ('[F]tenga[/F]', 'tenga'), ('[F]dedica[/F]', 'dedica')] [('[F]estés[/F]', 'estés'), ('[F]tu[/F]', 'tu'), ('[F]tengas[/F]', 'tengas'), ('[F]dedicas[/F]', 'dedicas')] NEUTRAL [] []
# Por eso son todos cool, son un poco tolos, ¿entendes lo que me digo? [('[F]sabe[/F]', 'sabe')] [('[F]sabes[/F]', 'sabes')] NEUTRAL [] []
# No me entienen. Me he quedado muy viejo y fuera de contacto, pero me parece ridículo. [] [] NEUTRAL [] []
# Yo no sé, pero me he visto ese espectáculo. ¿Qué es tu? [('[F]suya[/F]', 'suya')] [('[F]tuya[/F]', 'tuya')] NEUTRAL [] []
# You know what I am saying my extended family is out of States [('[F]Usted entiende[/F]', 'Usted entiende')] [('[F]Tú entiendes[/F]', 'Tú entiendes')] NEUTRAL [] []
# La dieta es la mayoría de su problema en cualquier caso. [('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu')] FORMAL ['su'] []
# Cuando eramos más jóvenes, tu casilla de teléfono y tu clip, eran un complemento de moda, y en realidad ya no lo son. [('[F]su[/F]', 'su'), ('[F]su[/F]', 'su'), ('[F]Su[/F]', 'Su'), ('[F]su[/F]', 'su')] [('[F]tu[/F]', 'tu'), ('[F]tu[/F]', 'tu'), ('[F]Tu[/F]', 'Tu'), ('[F]tu[/F]', 'tu')] INFORMAL [] ['tu', 'tu', 'tu']
# defaultdict(<class 'int'>, {'ref_matched_count_NEUTRAL': 65, 'ref_matched_count_INFORMAL': 17, 'ref_matched_count_FORMAL': 18})
# n_matched: 35
# Total samples: 100
# True neutral: 5
